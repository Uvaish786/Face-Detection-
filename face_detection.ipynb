# %%
import cv2
import sys
import os
import easygui
# from Adafruit_IO import Client
# aio = Client('shub30agg', 'da30b62b5c1a4af6a14672d05f57f999')

# %%
faceCascade = cv2.CascadeClassifier("face.xml")
try:
    name = easygui.enterbox()
except:
    name = "random"
try:
    os.mkdir("dataset")
except:
    pass
try:
    os.mkdir("dataset"+"\\"+name)
except:
    pass
video_capture = cv2.VideoCapture(0)
new_path = "dataset\\"+name
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-0694ee3d7653> in <module>
#      13     pass
#      14 video_capture = cv2.VideoCapture(0)
# ---> 15 new_path = "dataset\\"+name
#
# TypeError: can only concatenate str (not "NoneType") to str

# %%
i = 0
while True:
    # Capture frame-by-frame
    ret, frame = video_capture.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces=faceCascade.detectMultiScale(gray, scaleFactor=1.2, minNeighbors=5, minSize=(100, 100), flags=cv2.CASCADE_SCALE_IMAGE)
    # Draw a rectangle around the faces
    for (x, y, w, h) in faces:
        i=i+1
        cv2.imwrite(new_path+"\\"+name +'_'+ str(i) + ".jpg", gray[y:y+h,x:x+w])
        print("file_saved")
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        print(i)
    # Display the resulting frame
    try:
        cv2.imshow('Video', frame)
    except:
        continue
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    if i+1>100:
        break
# When everything is done, release the capture
video_capture.release()
cv2.destroyAllWindows()
# Out:
# file_saved
# 1
# file_saved
# 2
# file_saved
# 3
# file_saved
# 4
# file_saved
# 5
# file_saved
# 6
# file_saved
# 7
# file_saved
# 8
# file_saved
# 9
# file_saved
# 10
# file_saved
# 11
# file_saved
# 12
# file_saved
# 13
# file_saved
# 14
# file_saved
# 15
# file_saved
# 16
# file_saved
# 17
# file_saved
# 18
# file_saved
# 19
# file_saved
# 20
# file_saved
# 21
# file_saved
# 22
# file_saved
# 23
# file_saved
# 24
# file_saved
# 25
# file_saved
# 26
# file_saved
# 27
# file_saved
# 28
# file_saved
# 29
# file_saved
# 30
# file_saved
# 31
# file_saved
# 32
# file_saved
# 33
# file_saved
# 34
# file_saved
# 35
# file_saved
# 36
# file_saved
# 37
# file_saved
# 38
# file_saved
# 39
# file_saved
# 40
# file_saved
# 41
# file_saved
# 42
# file_saved
# 43
# file_saved
# 44
# file_saved
# 45
# file_saved
# 46
# file_saved
# 47
# file_saved
# 48
# file_saved
# 49
# file_saved
# 50
# file_saved
# 51
# file_saved
# 52
# file_saved
# 53
# file_saved
# 54
# file_saved
# 55
# file_saved
# 56
# file_saved
# 57
# file_saved
# 58
# file_saved
# 59
# file_saved
# 60
# file_saved
# 61
# file_saved
# 62
# file_saved
# 63
# file_saved
# 64
# file_saved
# 65
# file_saved
# 66
# file_saved
# 67
# file_saved
# 68
# file_saved
# 69
# file_saved
# 70
# file_saved
# 71
# file_saved
# 72
# file_saved
# 73
# file_saved
# 74
# file_saved
# 75
# file_saved
# 76
# file_saved
# 77
# file_saved
# 78
# file_saved
# 79
# file_saved
# 80
# file_saved
# 81
# file_saved
# 82
# file_saved
# 83
# file_saved
# 84
# file_saved
# 85
# file_saved
# 86
# file_saved
# 87
# file_saved
# 88
# file_saved
# 89
# file_saved
# 90
# file_saved
# 91
# file_saved
# 92
# file_saved
# 93
# file_saved
# 94
# file_saved
# 95
# file_saved
# 96
# file_saved
# 97
# file_saved
# 98
# file_saved
# 99
# file_saved
# 100

# %%
import cv2
import os
from PIL import Image 
import pickle
import numpy as np
face_dict = {}
def get_images_and_labels(path):
    global face_dict
    names=os.listdir("dataset")
    image_paths=[]
    new_path="dataset"
    for name in names:
        image_paths.append([os.path.join(new_path+"\\"+name, f) for f in os.listdir(new_path+"\\"+name)])
    print(image_paths)
 # images will contains face images
    images = []
 # labels will contains the label that is assigned to the image
    labels = []
    nbr = 0
    i = 0
    j = 0
    for name in names:
        for image_path in image_paths[j]:
             # Read the image and convert to grayscale
            image_pil = Image.open(image_path).convert('L')
             # Convert the image format into numpy array
            image = np.array(image_pil, 'uint8')
            face_dict[j] = name
            print(face_dict)
            #nbr=int(''.join(str(ord(c)) for c in nbr))
            print(image_path)
             # Detect the face in the image
            faceCascade = cv2.CascadeClassifier('face.xml')
            faces = faceCascade.detectMultiScale(image)
             # If face is detected, append the face to images and the label to labels
            for (x, y, w, h) in faces:
                images.append(image[y: y + h, x: x + w])
                labels.append(j)
                cv2.imshow("Adding faces to traning set...", image[y: y + h, x: x + w])
                cv2.waitKey(10)
            i = i+1
        j = j+1
    return images,labels

def save_obj(obj, name ):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

#file_rename(path,names)
recognizer = cv2.face.LBPHFaceRecognizer_create()
recognizer.read('trainer\\trainer.yml')
images, labels = get_images_and_labels('dataset\\random')
#cv2.imshow('test',images[0])
#cv2.wai.tKey(1)
save_obj(face_dict,"trainer\\trained_faces")
recognizer.train(images, np.array(labels))
recognizer.save('trainer\\trainer.yml')
cv2.destroyAllWindows()
# Out:
# [[], [], [], [], ['dataset\\sidd\\sidd_1.jpg', 'dataset\\sidd\\sidd_10.jpg', 'dataset\\sidd\\sidd_100.jpg', 'dataset\\sidd\\sidd_11.jpg', 'dataset\\sidd\\sidd_12.jpg', 'dataset\\sidd\\sidd_13.jpg', 'dataset\\sidd\\sidd_14.jpg', 'dataset\\sidd\\sidd_15.jpg', 'dataset\\sidd\\sidd_16.jpg', 'dataset\\sidd\\sidd_17.jpg', 'dataset\\sidd\\sidd_18.jpg', 'dataset\\sidd\\sidd_19.jpg', 'dataset\\sidd\\sidd_2.jpg', 'dataset\\sidd\\sidd_20.jpg', 'dataset\\sidd\\sidd_21.jpg', 'dataset\\sidd\\sidd_22.jpg', 'dataset\\sidd\\sidd_23.jpg', 'dataset\\sidd\\sidd_24.jpg', 'dataset\\sidd\\sidd_25.jpg', 'dataset\\sidd\\sidd_26.jpg', 'dataset\\sidd\\sidd_27.jpg', 'dataset\\sidd\\sidd_28.jpg', 'dataset\\sidd\\sidd_29.jpg', 'dataset\\sidd\\sidd_3.jpg', 'dataset\\sidd\\sidd_30.jpg', 'dataset\\sidd\\sidd_31.jpg', 'dataset\\sidd\\sidd_32.jpg', 'dataset\\sidd\\sidd_33.jpg', 'dataset\\sidd\\sidd_34.jpg', 'dataset\\sidd\\sidd_35.jpg', 'dataset\\sidd\\sidd_36.jpg', 'dataset\\sidd\\sidd_37.jpg', 'dataset\\sidd\\sidd_38.jpg', 'dataset\\sidd\\sidd_39.jpg', 'dataset\\sidd\\sidd_4.jpg', 'dataset\\sidd\\sidd_40.jpg', 'dataset\\sidd\\sidd_41.jpg', 'dataset\\sidd\\sidd_42.jpg', 'dataset\\sidd\\sidd_43.jpg', 'dataset\\sidd\\sidd_44.jpg', 'dataset\\sidd\\sidd_45.jpg', 'dataset\\sidd\\sidd_46.jpg', 
jpg
# {4: 'sidd'}
# dataset\sidd\sidd_78.jpg
# {4: 'sidd'}
# dataset\sidd\sidd_79.jpg
# {4: 'sidd'}
# dataset\sidd\sidd_8.jpg
# {4: 'sidd'}
# dataset\sidd\sidd_80.jpg
# {4: 'sidd'}
# dataset\sidd\sidd_81.jpg
# {4: 'sidd'}
# dataset\sidd\sidd_82.jpg
# {4: 'sidd'}
# dataset\sidd\sidd_83.jpg
# {4: 'sidd'}
# dataset\sidd\sidd_84.jpg
# {4: 'sidd'}
# dataset\sidd\sidd_85.jpg
# {4: 'sidd'}
# dataset\sidd\sidd_86.jpg
# {4: 'sidd'}
# dataset\sidd\sidd_87.jpg
# {4: 'sidd'}
# dataset\sidd\sidd_88.jpg
# {4: 'sidd'}
# dataset\sidd\sidd_89.jpg
# {4: 'sidd'}
# dataset\sidd\sidd_9.jpg
# {4: 'sidd'}
# dataset\sidd\sidd_90.jpg
# {4: 'sidd'}
# dataset\sidd\sidd_91.jpg
# {4: 'sidd'}
# dataset\sidd\sidd_92.jpg
# {4: 'sidd'}
# dataset\sidd\sidd_93.jpg
# {4: 'sidd'}
# dataset\sidd\sidd_94.jpg
# {4: 'sidd'}
# dataset\sidd\sidd_95.jpg
# {4: 'sidd'}
# dataset\sidd\sidd_96.jpg
# {4: 'sidd'}
# dataset\sidd\sidd_97.jpg
# {4: 'sidd'}
# dataset\sidd\sidd_98.jpg
# {4: 'sidd'}
# dataset\sidd\sidd_99.jpg

# %%
import cv2
import pickle
recognizer = cv2.face.LBPHFaceRecognizer_create()
recognizer.read('trainer\\trainer.yml')
cascadePath = "face.xml"
faceCascade = cv2.CascadeClassifier(cascadePath)
nbr_predicted, conf=0,0
with open("trainer\\trained_faces.pkl",'rb') as f:
    face_dict = pickle.load(f)
# face_dict=load_obj("trainer\\trained_faces")
cam = cv2.VideoCapture(0)
pre_detect = 0
while True:
    ret, im = cam.read()
    gray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray, scaleFactor=1.2, minNeighbors=5, minSize=(100, 100), flags=cv2.CASCADE_SCALE_IMAGE)
    for(x,y,w,h) in faces:
        nbr_predicted, conf = recognizer.predict(gray[y:y+h,x:x+w])
        print(round(100 - conf, 2))
        cv2.rectangle(im,(x-50,y-50),(x+w+50,y+h+50),(225,0,0),2)
        label = face_dict[nbr_predicted]
        if(round(100 - conf, 2)>30):
            cv2.putText(im,str(label),(x,y+h),cv2.FONT_HERSHEY_SIMPLEX, 1,(255,255,255),2)
#             detect = 1
        else :
            cv2.putText(im,str("UNKNOWN"),(x,y+h),cv2.FONT_HERSHEY_SIMPLEX, 1,(255,255,255),2)
            detect = 0
        cv2.putText(im,"press esc to exit",(x-45,y-40),cv2.FONT_HERSHEY_SIMPLEX, 0.5,(255,255,0),2)
#         if pre_detect != detect:
#             aio.send('foo',detect)
#             pre_detect = detect
    cv2.imshow('im',im)
    k = cv2.waitKey(1) & 0xff
    if k == 27:
        break
cam.release()
cv2.destroyAllWindows()
# Out:
# 59.67
# 57.5
# 56.15
# 57.68
# 59.05
# 59.42
# 57.69
# 58.49
# 59.29
# 59.29
# 59.47
# 57.77
# 58.29
# 58.29
# 59.71
# 59.08
# 59.02
# 58.18
# 58.35
# 59.17
# 58.73
# 58.73
# 59.54
# 60.1
# 58.72
# 58.84
# 58.84
# 58.85
# 60.59
# 59.29
# 59.22
# 60.1
# 60.05
# 59.69
# 59.02
# 59.25
# 59.25
# 59.86
# 60.74
# 61.15
# 60.56
# 60.41
# 60.41
# 58.79
# 60.21
# 59.01
# 59.82
# 60.14
# 58.93
# 58.93
# 60.39
# 59.27
# 59.54
# 58.53
# 58.53
# 58.91
# 59.3
# 59.48
# 59.48
# 59.51
# 59.58
# 58.36
# 58.36
# 59.21
# 59.47
# 60.25
# 60.42
# 60.55
# 60.55
# 59.28
# 61.55
# 59.87
# 59.87
# 59.41
# 59.52
# 57.17
# 58.95
# 59.85
# 58.8
# 58.8
# 59.81
# 59.62
# 56.85
# 56.68
# 56.2
# 56.2
# 58.36
# 59.05
# 60.13
# 53.58
# 60.68
# 60.17
# 61.69
# 61.43
# 61.43
# 62.84
# 62.54
# 64.48
# 64.9
# 62.9
# 62.9
# 63.25
# 62.95
# 63.44
# 63.24
# 62.59
# 63.62
# 64.15
# 64.15
# 62.72
# 65.01
# 62.68
# 62.68
# 63.57
# 64.65
# 62.41
# 62.75
# 64.14
# 64.81
# 63.57
# 63.5
# 63.5
# 62.57
# 61.31
# 67.33
# 62.33
# 62.36
# 60.22
# 61.99
# 68.16
# 67.76
# 68.02
# 66.3
# 66.3
# 61.14
# 65.51
# 63.87
# 61.09
# 60.85
# 60.42
# 61.32
# 61.52
# 62.22
# 60.61
# 59.9
# 61.16
# 61.92
# 65.61
# 64.79
# 63.88
# 63.88
# 64.7
# 64.7
# 62.3
# 60.7
# 60.7
# 57.8
# 59.77
# 59.77
# 62.59
# 58.12
# 58.12
# 62.84
# 63.41
# 63.41
# 64.16
# 64.26
# 64.26
# 59.51
# 65.08
# 65.08
# 57.71
# 62.5
# 62.5
# 57.31
# 60.63
# 60.63
# 61.79
# 62.41
# 62.41
# 60.92
# 62.38
# 62.38
# 62.69
# 62.26
# 62.26
# 63.7
# 63.7
# 63.17
# 63.17
# 63.69
# 61.28
# 61.69
# 58.78
# 58.78
# 59.46
# 62.83
# 62.09
# 62.09
# 59.48
# 58.34
# 58.34
# 59.62
# 67.07
# 67.07
# 60.39
# 60.39
# 63.43
# 57.09
# 63.35
# 63.35
# 65.39
# 63.76
# 63.76
# 64.17
# 61.06
# 61.06
# 59.29
# 59.29
# 65.58
# 65.62
# 65.62
# 62.03
# 63.51
# 63.51
# 61.81
# 65.32
# 65.32
# 63.75
# 65.48
# 65.48
# 64.2
# 65.4
# 65.4
# 64.6
# 65.02
# 65.02
# 63.89
# 65.36
# 65.36
# 65.45
# 63.41
# 63.41
# 65.87
# 63.98
# 63.98
# 61.81
# 63.7
# 63.7
# 63.64
# 63.69
# 60.34
# 60.34
# 63.05
# 62.99
# 62.99
# 58.23
# 57.23
# 57.23
# 65.12
# 63.4
# 63.4
# 56.22
# 56.22
# 56.9
# 58.95
# 58.95
# 56.1
# 56.1
# 58.11
# 57.66
# 57.66
# 63.01
# 64.13
# 63.57
# 63.57
# 65.91
# 65.69
# 65.69
# 59.86
# 66.65
# 66.65
# 58.95
# 58.86
# 58.86
# 61.58
# 63.49
# 63.49
# 65.4
# 66.39
# 66.39
# 64.63
# 64.35
# 64.35
# 61.3
# 59.33
# 59.33
# 62.68
# 66.26
# 66.26
# 66.13
# 66.13
# 62.88
# 64.8
# 64.8
# 59.94
# 59.51
# 59.51
# 61.4
# 61.4
# 62.65
# 64.99
# 64.99
# 61.53
# 61.53
# 64.77
# 61.16
# 61.16
# 61.65
# 63.86
# 63.86
# 64.75
# 61.76
# 63.26
# 63.26
# 63.55
# 62.52
# 62.52
# 63.43
# 63.43
# 62.54
# 62.39
# 62.39
# 63.8
# 64.81
# 64.81
# 63.55
# 64.72
# 64.72
# 64.51
# 63.12
# 63.12
# 60.78
# 64.86
# 64.86
# 63.8
# 63.8
# 63.75
# 63.75
# 60.29
# 64.4
# 64.4
# 61.12
# 61.12
# 65.4
# 65.4
# 66.31
# 65.47
# 65.47
# 64.07
# 64.07
# 64.9
# 65.54
# 63.99
# 65.93
# 65.93
# 62.44
# 63.61
# 63.61
# 63.59
# 63.05
# 63.05
# 62.01
# 64.21
# 64.21
# 62.62
# 57.02
# 57.02
# 62.46
# 63.04
# 63.04
# 63.39
# 64.4
# 64.4
# 62.79
# 61.98
# 61.98
# 62.24
# 63.07
# 63.07
# 63.51
# 63.12
# 63.12
# 61.4
# 58.98
# 58.98
# 59.29
# 61.39
# 58.82
# 61.02
# 64.57
# 66.69
# 66.69
# 58.74
# 58.74
# 67.12
# 66.39
# 66.39
# 66.82
# 66.82
# 66.3
# 66.3
# 65.94
# 65.54
# 65.54
